# %% [markdown]
# **Running Ollama locally with Docker**
#
# - pull the ollama image (about 5Gig)
# - The GPU mode only works on linux an windows
# - run the ollama image on port 11434
# - docker exec into ollama and pull the required model

# %% [markdown]
# **Using Ollama model locally**

# %%
# !pip install -q -U ollama
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# **Start your ollama container and pull the model**

# %%
from ollama import Client

client = Client(
    host="http://localhost:11434"
)

response = client.chat(
    model="gemma2:2b",
    messages=[
        {"role": "system", "content": "You are a helpful chat assistant"},
        {"role": "user", "content": "What is Artificial intelligence? Explain in short"}
    ],
    stream=True
)

for chunk in response:
    print(chunk["message"]["content"], end="", flush=True)
# Out:
#  Artificial Intelligence (AI) refers to the simulation of human intelligence processes by machines, especially computer systems. These processes include learning (the acquisition of information and rules for using that information), reasoning (using logic, mathematics, and common sense to solve problems), and self-correction. The goal of AI is to create systems capable of performing tasks that would normally require human intelligence. This can range from simple tasks like voice recognition or driving a car, to complex tasks like understanding natural language, recognizing patterns in large datasets, and making decisions based on those patterns. AI can be categorized as either weak AI (designed to perform a specific task) or strong AI (able to understand, learn, and respond like a human across virtually all tasks).
