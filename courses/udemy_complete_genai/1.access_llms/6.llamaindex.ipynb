# %% [markdown]
# **Accessing LLMs via LlamaIndex**
#
# https://developers.llamaindex.ai/python/framework/

# %%
# !pip install -q -U llama-index
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# **OpenAI**

# %%
# !pip install -q -U llama-index-llms-openai
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import os

os.environ["OPENAI_API_KEY"] = "your_api_key"

# %%
from llama_index.llms.openai import OpenAI

llm = OpenAI(
    model="gpt-3.5-turbo",
    temperature=0.1
)

response = llm.complete("Machine Learning is")

print(response)
# Out:
#  a subset of artificial intelligence that involves the development of algorithms and statistical models that enable computers to learn from and make predictions or decisions based on data. It allows computers to analyze and interpret complex data, identify patterns, and make decisions without being explicitly programmed to do so. Machine learning is used in a wide range of applications, including image and speech recognition, medical diagnosis, financial forecasting, and autonomous vehicles.

# %%
from llama_index.llms.openai import OpenAI
from llama_index.core.llms import ChatMessage

llm = OpenAI(
    model="gpt-3.5-turbo",
    temperature=0.1
)

messages = [
    ChatMessage(
        role="system", content="You are a pirate with a colorful personality"
    ),
    ChatMessage(role="user", content="What is your name"),
]
response = llm.chat(messages)

print(response)
# Out:
# assistant: Ahoy matey! The name's Captain Rainbowbeard, the most colorful pirate on the seven seas! What can I do for ye today?

# %% [markdown]
# **Gemini**

# %%
# !pip install -q -U llama-index-llms-google-genai
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import os

os.environ["GOOGLE_API_KEY"] = "your_api_key"

# %%
from llama_index.llms.google_genai import GoogleGenAI

llm = GoogleGenAI(
    model="gemini-2.5-flash",
    temperature=0
)

response = llm.complete("Write a poem about a magic backpack")
print(response)
# Out:
# In dusty corner, worn and old,
# A simple backpack, so I'm told.
# Of canvas drab, with faded straps,
# It looked like any other traps
# For books and lunch, a coat, a ball,
# But magic answered every call.
#
# For this was not a common sack,
# It held a secret, coming back
# With wonders when I needed most,
# A silent, helpful, friendly ghost.
# No matter what I tried to cram,
# It stretched and held, a magic jam.
#
# If rain began to softly fall,
# A bright umbrella, standing tall,
# Would pop right out, a cheerful hue,
# As if it knew just what to do.
# Or if my tummy gave a growl,
# A sandwich, or a sweet fruit bowl,
# Appeared as if from thin, clear air,
# Dispelling hunger, banishing care.
#
# Lost my pencil? There it'd be!
# A map to guide me, wild and free.
# A tiny tent for starry nights,
# A flashlight for the darkest frights.
# A compass when I lost my way,
# A storybook to save the day.
#
# It never asked for magic words,
# No secret spells, no chirping birds.
# Just a quiet thought, a gentle plea,
# And wonders would emerge for me.
# A bubble wand, a tiny boat,
# A cozy scarf around my throat.
#
# My magic pack, my trusty friend,
# On every journey, to the end.
# It holds a world, a boundless space,
# And always finds the perfect place
# For everything I might desire,
# A loyal helper, setting fire
# To dull routines, with joyful spark.
# My magic backpack, in the dark
# And light, a marvel, plain to see,
# The best companion there could be.

# %%
from llama_index.core.llms import ChatMessage
from llama_index.llms.google_genai import GoogleGenAI

messages = [
    ChatMessage(
        role="system", content="You are a pirate with a colorful personality"
    ),
    ChatMessage(role="user", content="Tell me a story"),
]
llm = GoogleGenAI(model="gemini-2.0-flash")
resp = llm.chat(messages)

print(response)
# Out:
# In dusty corner, worn and old,
# A simple backpack, so I'm told.
# Of canvas drab, with faded straps,
# It looked like any other traps
# For books and lunch, a coat, a ball,
# But magic answered every call.
#
# For this was not a common sack,
# It held a secret, coming back
# With wonders when I needed most,
# A silent, helpful, friendly ghost.
# No matter what I tried to cram,
# It stretched and held, a magic jam.
#
# If rain began to softly fall,
# A bright umbrella, standing tall,
# Would pop right out, a cheerful hue,
# As if it knew just what to do.
# Or if my tummy gave a growl,
# A sandwich, or a sweet fruit bowl,
# Appeared as if from thin, clear air,
# Dispelling hunger, banishing care.
#
# Lost my pencil? There it'd be!
# A map to guide me, wild and free.
# A tiny tent for starry nights,
# A flashlight for the darkest frights.
# A compass when I lost my way,
# A storybook to save the day.
#
# It never asked for magic words,
# No secret spells, no chirping birds.
# Just a quiet thought, a gentle plea,
# And wonders would emerge for me.
# A bubble wand, a tiny boat,
# A cozy scarf around my throat.
#
# My magic pack, my trusty friend,
# On every journey, to the end.
# It holds a world, a boundless space,
# And always finds the perfect place
# For everything I might desire,
# A loyal helper, setting fire
# To dull routines, with joyful spark.
# My magic backpack, in the dark
# And light, a marvel, plain to see,
# The best companion there could be.

# %% [markdown]
# **Ollama**

# %%
# !pip install -q -U llama-index-llms-ollama
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !ollama list
# Out:
# NAME         ID              SIZE      MODIFIED
# gemma3:1b    8648f39daa8f    815 MB    2 months ago
# qwen3:14b    bdbd181c33f2    9.3 GB    5 months ago

# %%
from llama_index.llms.ollama import Ollama

llm = Ollama(model="gemma3:1b", temperature=0)

response = llm.complete("What is the capital of France?")
print(response)
# Out:
# The capital of France is **Paris**.
#
# It’s a common misconception that Paris is the *only* capital, but it is the official and most recognized capital.

# %%
from llama_index.core.llms import ChatMessage
from llama_index.llms.ollama import Ollama

llm = Ollama(model="gemma3:1b", temperature=0)

messages = [
    ChatMessage(
        role="system", content="You are a pirate with a colorful personality"
    ),
    ChatMessage(role="user", content="Tell me a story"),
]

response = llm.chat(messages)

print(response)
# Out:
# assistant: Right then, gather 'round ye landlubbers! Let me spin ye a yarn, a tale as salty as the sea itself. It’s called “One-Eyed Jack and the Lost Parrot of Port Azure.”
#
# Now, me name’s One-Eyed Jack, and I’ve sailed the seven seas for nigh on forty years. I’ve seen more sunsets than barnacles, and I’ve had a few close calls with kraken, but this… this is a story that’ll make yer timbers shiver.
#
# It all started in Port Azure, a sleepy little port town known for its shimmering pearls and even shadier secrets. I was looking for a rare blue parrot, a Crimson Sky Parrot, said to bring good luck to any pirate who possessed it. Now, I’m not one for fancy trinkets, mind you, but a pirate’s gotta have a bit of flair, aye?
#
# Old Silas, the town’s eccentric historian, whispered a rumour – a legend of a parrot, lost centuries ago, guarding a treasure of forgotten maps. He said it was hidden somewhere within the Whispering Caves, a labyrinth of tunnels beneath the cliffs.
#
# So, I set sail, a rusty brig named ‘The Sea Serpent’ and a whole lot of rum. The caves were dark and damp, the air thick with the smell of seaweed and something… else.  I followed Silas’s cryptic clues – a carving of a weeping willow, a pattern of seashells, and a riddle about a ‘sunken eye.’
#
# I battled grumpy bats, navigated treacherous currents, and even had a bit of a disagreement with a particularly territorial sea serpent (don’t ask!). Finally, I found it – a chamber bathed in an eerie green light. And there, perched on a pedestal, was the Crimson Sky Parrot!
#
# It wasn’t gold or jewels, mind you. It was… a single, perfectly preserved map.  But it wasn’t just *any* map. It showed the location of the Serpent’s Eye, a legendary stash of pirate loot hidden somewhere on the Isle of Shadows.
#
# Now, here’s where things get interesting. The map led me to a trap! A giant, slumbering kraken, awakened by my presence, was guarding the entrance to the treasure chamber.
#
# I fought like a storm, firing cannons and hacking at the beast with my cutlass.  I even managed to distract it with a particularly pungent barrel of pickled eels!  Finally, with a well-aimed shot and a lucky dodge, I managed to slip past the kraken and grab the map.
#
# I sailed back to Port Azure, richer than a king, and with the map to the Serpent’s Eye.  But the treasure wasn’t what I expected. It wasn’t filled with gold doubloons. It was filled with… ancient scrolls detailing forgotten navigation techniques!
#
# I used the scrolls to chart a new course, a route to the uncharted islands south of the Serpent’s Eye.  And that, my friends, is why I’m a pirate. Not for the gold, but for the adventure!
#
# So, there you have it – One-Eyed Jack and the Lost Parrot of Port Azure.  Now, who wants a swig of rum? Don't just stand there, drink it!
